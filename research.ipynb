# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('./data/cleaned.csv')

# %%
df.head()
# Out:
#         Category                                            Content
# 0     технологии  microsoft анонсирова флагманск смартфон жидкос...
# 1         туризм  египет продл российск турист возможн получа ви...
# 2   происшествия  станц автов человек попа поезд молод человек з...
# 3       общество  британк отмет 101лет управл танк жительниц вел...
# 4  строительство  северн город расширя ипотечн программ североза...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 127717 entries, 0 to 127716
# Data columns (total 2 columns):
# Category    127717 non-null object
# Content     127717 non-null object
# dtypes: object(2)
# memory usage: 1.9+ MB

# %%
plt.figure(figsize=(12, 8))
df['Category'].value_counts().plot(kind='bar')
plt.title('Распределение новостей по категориям')
plt.show()

# %%
df['Category'].value_counts()
# Out:
# происшествия           38411
# общество               29443
# власть                 13220
# город                  11628
# бизнес                  8705
# спорт                   8487
# финансы                 4415
# авто                    2988
# благотворительность     1989
# строительство           1854
# технологии              1506
# жкх                     1451
# туризм                  1107
# деньги                   985
# недвижимость             639
# работа                   384
# выборы                   212
# дороги                    96
# личная жизнь              81
# культура                  59
# афиша                     31
# здоровье и красота        17
# доступная среда            7
# домашний очаг              2
# Name: Category, dtype: int64

# %%
df['Length'] = df['Content'].apply(lambda s: len(s.split()))

# %%
df.head()
# Out:
#        Category                                            Content  Length
# 0        бизнес  дочк юлмарт обжалова введен процедур наблюден ...     129
# 1  происшествия  подмосков напа двух сотрудник росгвард сотрудн...      77
# 2  происшествия  мужчин отда полмиллион лжеэкстрасенс телевиден...     157
# 3        власть  сотрудник дум нача требова отчет пост соцсет в...     137
# 4        туризм  российск турист аннулир путевк итал землетрясе...     170

# %%
plt.figure(figsize=(12, 8))
df.groupby('Category')['Length'].mean().plot(kind='bar')
plt.title('Средняя длина новости (в словах) по категориям')
plt.show()

# %%
df.boxplot(column='Length', by='Category', figsize=(12, 8), rot=90)
plt.title('Длина новости (в словах) по категориям')
plt.show()

# %%
10000/240
# Out:
# 41.666666666666664
