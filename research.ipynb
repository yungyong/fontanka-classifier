# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Данные до обработки

# %%
df_initial = pd.read_csv('./data/initial.csv')

# %%
df_initial.head()
# Out:
#         Category                                            Content
# 0     технологии  microsoft анонсировал флагманские смартфоны с ...
# 1         туризм  египет продлил для российских туристов возможн...
# 2   происшествия  на станции автово человек попал под поезд моло...
# 3       общество  британка отметила 101летие управляя танком жит...
# 4  строительство  северный город расширяет ипотечную программу с...

# %%
df_initial.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 128273 entries, 0 to 128272
# Data columns (total 2 columns):
# Category    128273 non-null object
# Content     128273 non-null object
# dtypes: object(2)
# memory usage: 2.0+ MB

# %%
df_initial['Category'].value_counts()
# Out:
# происшествия                                        38397
# общество                                            29333
# власть                                              13220
# город                                               11319
# бизнес                                               8532
# спорт                                                8471
# финансы                                              4415
# авто                                                 2753
# доброе дело                                          1983
# строительство                                        1816
# технологии                                           1506
# жкх                                                  1451
# туризм                                               1107
# деньги                                                985
# недвижимость                                          637
# работа                                                383
# 47новостей из ленинградской области                   308
# водитель петербурга                                   230
# выборы                                                212
# бизнес-трибуна                                        148
# точка опоры                                           110
# дороги                                                 96
# говорим и показываем                                   72
# личная жизнь                                           58
# русфонд                                                48
# лидеры финского бизнеса                                43
# фонтанка.fi                                            41
# лахта центр                                            38
# спроси сам                                             37
# фонтанка-sup                                           37
#                                                     ...
# лушников                                                1
# технические требования                                  1
# год n300                                                1
# театры                                                  1
# опасная передача                                        1
# "семейная игра: устрой ребенку праздник"                1
# охта центр                                              1
# куда пойти подростку, пока все в офисе                  1
# неизвестная финляндия: куда поехать на выходные?        1
# «проверка связи»: где поймать сеть?                     1
# фонтанка-project                                        1
# медиа киты                                              1
# контур культуры                                         1
# андрей заостровцев                                      1
# фото                                                    1
# евгений вышенков                                        1
# реклама                                                 1
# расположение                                            1
# квадрат                                                 1
# конкурс от «фонтанки»: «умная дача на удачу»            1
# чпх                                                     1
# лев лурье                                               1
# первая страница                                         1
# марианна баконина                                       1
# профессионал                                            1
# вещи победы                                             1
# история                                                 1
# в теме                                                  1
# видео                                                   1
# водитель петербурга.live                                1
# Name: Category, Length: 118, dtype: int64

# %% [markdown]
# # Данные после обработки

# %%
df = pd.read_csv('./data/cleaned.csv')

# %%
df.head()
# Out:
#         Category                                            Content
# 0     технологии  microsoft анонсирова флагманск смартфон жидкос...
# 1         туризм  египет продл российск турист возможн получа ви...
# 2   происшествия  станц автов человек попа поезд молод человек з...
# 3       общество  британк отмет 101лет управл танк жительниц вел...
# 4  строительство  северн город расширя ипотечн программ североза...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 127691 entries, 0 to 127716
# Data columns (total 2 columns):
# Category    127691 non-null object
# Content     127691 non-null object
# dtypes: object(2)
# memory usage: 7.9+ MB

# %%
df['Category'].value_counts()
# Out:
# происшествия           38411
# общество               29443
# власть                 13220
# город                  11628
# бизнес                  8705
# спорт                   8487
# финансы                 4415
# авто                    2988
# благотворительность     1989
# строительство           1854
# технологии              1506
# жкх                     1451
# туризм                  1107
# деньги                   985
# недвижимость             639
# работа                   384
# выборы                   212
# дороги                    96
# культура                  90
# личная жизнь              81
# Name: Category, dtype: int64

# %%
plt.figure(figsize=(12, 8))
df['Category'].value_counts().plot(kind='bar')
plt.title('Распределение новостей по категориям')
plt.show()

# %%
df['Length'] = df['Content'].apply(lambda s: len(s.split()))

# %%
df.head()
# Out:
#         Category                                            Content  Length
# 0     технологии  microsoft анонсирова флагманск смартфон жидкос...     173
# 1         туризм  египет продл российск турист возможн получа ви...     102
# 2   происшествия  станц автов человек попа поезд молод человек з...      75
# 3       общество  британк отмет 101лет управл танк жительниц вел...      96
# 4  строительство  северн город расширя ипотечн программ североза...     216

# %%
plt.figure(figsize=(12, 8))
df.groupby('Category')['Length'].mean().plot(kind='bar')
plt.title('Средняя длина новости (в словах) по категориям')
plt.show()

# %%
df.boxplot(column='Length', by='Category', figsize=(12, 8), rot=90)
plt.title('Длина новости (в словах) по категориям')
plt.show()
